# %% [markdown]
# #🏁 Reto Final 🏁

# %% [markdown]
# ## 🤖 PROYECTO FINAL DE MACHINE LEARNING NIVEL I:
# TALENTO ESPECIALIZADO 2023
#
# Realizado por:
#
# * Harold Andrés Arias
#
# * Harold Montejo
#
# * Sara Ospina
#
# * Catalina Gonzalez
#
# * Jesus Otero

# %% [markdown]
# # 💾**. Documentacion**
#
# **•	Objetivo General**
#
# El objetivo General del Proyecto es Obtener  información demográfica de personas a las que se les realizó una encuesta para conocer sus preferencias en cuanto a plataformas de streaming para ver series y películas.
#
# **•	Alcance**
#
# En concreto 122 personas fueron encuestadas para tener una muestra sólida y variada de información de información. No se espera que la encuesta sea utilizada para otros fines mas allá de la exploración académica de las librerías empleadas para el análisis de datos de en Python
#
# **•	Funcionalidades**
#
# El algoritmo que se utiliza está escrito en Python. Por medio de las funcionalidades de las librerías
# **-	Pandas:**  que es utilizada para la manipulación y análisis de datos. Que ofrece DataFrames y Series para manipular y analizar datos de forma eficiente, lo que facilita la limpieza, filtrado y transformación de datos.
# **-	Numpy:**  Esta nos proporciona arrelgos   multidimensionales que son eficientes en términos de almacenamiento y operaciones matemáticas. En el caso de este proyecto para los cálculos de información como media, percentil entre otros.
# **-	Matplotlib:** esta herramienta de visualización nos permite crear gráficos y visualizaciones de datos de alta calidad.
#
# **•	Planificación y Cronogramas.**
# El proyecto se empezó a desarrollar en Python el día 22 de octubre de 2023 con el objetivo de der desarrollado y entregado el día 1 de noviembre de 2023
# El proyecto se dividió en el desarrollo en dos fases.
#
# **-	Fase 1:** Implementación de la encuesta.
# El grupo se reunió para discutir las preguntas a implementar en la encuesta con el fin de orientar las preguntas para obtener la información necesaria que conteste a las siguientes preguntas.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# **- Fase 2:** Tabulacion de la información
# De acuerdo a la información suministrada por los 122 individuos se puede responder a los siguientes cuestionamientos. Estas preguntas se adaptaron a al tema de la encuesta que este caso fueron las plataformas de streaming de series películas más utilizadas.  A continuación explicaremos el código aplicado de cada una de las preguntas
#
# ¿Cuántas personas {x} son mujeres?
#
# ![image.png](data:image/png;base64,...)
#
# en esta pregunta como en las siguientes se está utilizando un DataFrame que se llama df1 que se está filtrando para incluir solo las filas donde el valor pGenero sea “Femenino” por lo que el DataFrame df_femenino contendrá solo las filas de género femenino. Luego el código toma la columna pGeneroPel que representa los géneros cinematográficos  escogidos por las personas y cuenta cuantas veces aparece cada género escogido por las personas por medio de un value_counts( ) El resultado es un objeto que tiene cada género y el número de veces que aparece.
# Luego, reset_index() se utiliza para reiniciar el índice de las filas del DataFrame resultante, para que tenga un índice numérico de forma predeterminada.
# Y para finalizar el df_final que impreso contiene la información sobre cuantas mujeres eligieron cada genero cinematografico
#
#
# ¿Cuántas personas {x} son hombres?
#
# ![image.png](data:image/png;base64,...)
#
# Se está utilizando un DataFrame que se llama df1 que se está filtrando para incluir solo las filas donde el valor pGenero sea “Masculino” por lo que el DataFrame df_masculino contendrá solo las filas de género masculino. Luego el código toma la columna pGeneroPel que representa los géneros cinematográficos  escogidos por las personas y cuenta cuantas veces aparece cada género escogido por las personas por medio de un value_counts( ) El resultado es un objeto que tiene cada género y el número de veces que aparece.
# Luego, reset_index() se utiliza para reiniciar el índice de las filas del DataFrame resultante, para que tenga un índice numérico de forma predeterminada.
# Y para finalizar el df_final que impreso contiene la información sobre cuántos hombres eligieron cada género cinematográfico
#
# ¿Cuántas personas {x} son de otro género?
#
# ![image.png](data:image/png;base64,...)
#
#
# Se está utilizando un DataFrame que se llama df1 que se está filtrando para incluir solo las filas donde el valor pGenero sea “Prefiero no decirlo” por lo que el DataFrame df_otro contendrá solo las filas de género otro. Luego el código toma la columna pGeneroPel que representa los géneros cinematográficos escogidos por las personas y cuenta cuantas veces aparece cada género escogido por las personas por medio de un value_counts( ) El resultado es un objeto que tiene cada género y el número de veces que aparece.
# Luego, reset_index() se utiliza para reiniciar el índice de las filas del DataFrame resultante, para que tenga un índice numérico de forma predeterminada.
# Y para finalizar el df_final que impreso contiene la información sobre cuántos individuos eligieron cada género cinematográfico
#
# ¿Cuántas personas {x} tienen más de 18 años y menos de 30 años?
#
# ![image.png](data:image/png;base64,...)
#
# se está tomando un DataFrame llamado df1 y se está filtrando para incluir solo las filas donde el valor de la columna pEdad esté entre 18 y 30 años. Esto significa que df_edad1 contendrá solo las filas donde las personas tienen entre 18 y 30 años.
# En resumen el código filtra un DataFrame para incluir solo a las personas que tienen entre 18 y 30 años, luego cuenta cuántas veces aparece cada género cinematográfico entre esas personas y presenta los resultados en un DataFrame llamado df_final1. Esto proporcionaría información sobre las preferencias de género cinematográfico específicas de las personas jóvenes en el conjunto de datos.
#
# ¿Cuántas personas {x} tienen más de 30 años y menos de 50 años?
#
# ![image.png](data:image/png;base64,...)
#
# se está tomando un DataFrame llamado df1 y se está filtrando para incluir solo las filas donde el valor de la columna pEdad esté entre 30 y 50 años. Esto significa que df_edad2 contendrá solo las filas donde las personas tienen entre 30 y 50 años.
# En resumen el código filtra un DataFrame para incluir solo a las personas que tienen entre 30 y 50 años, luego cuenta cuántas veces aparece cada género cinematográfico entre esas personas y presenta los resultados en un DataFrame llamado df_final2. Esto proporcionaría información sobre las preferencias de género cinematográfico específicas de las personas en el conjunto de datos.
#
# ¿Cuántas personas {x} tienen más de 50 años?
#
# ![image.png](data:image/png;base64,...)
#
# se está tomando un DataFrame llamado df1 y se está filtrando para incluir solo las filas donde el valor de la columna pEdad esté mayor a 50 años. Esto significa que df_edad3 contendrá solo las filas donde las personas tienen más de 50 años.
# En resumen el código filtra un DataFrame para incluir solo a las personas que tienen más de 50 años, luego cuenta cuántas veces aparece cada género cinematográfico entre esas personas y presenta los resultados en un DataFrame llamado df_final3. Esto proporcionaría información sobre las preferencias de género cinematográfico específicas de las personas en el conjunto de datos.
#
# ¿Cuántas personas {x} son colombianas?
#
# ![image.png](data:image/png;base64,...)
#
# se está tomando un DataFrame llamado df1 y se está filtrando para incluir solo las filas donde el valor de la columna pNatal sea igual a Colombia. Esto significa que df_pais contendrá solo las filas donde las personas son de nacionalidad colombiana.
# En resúmen el código filtra un DataFrame para incluir solo a las personas que tienen cuyo país natal es Colombia, luego cuenta cuántas veces aparece cada género cinematográfico entre esas personas y presenta los resultados en un DataFrame llamado df_final. Esto proporcionaría información sobre las preferencias de género cinematográfico específicas de las personas jóvenes en el conjunto de datos.
# **Para no entrar en redundancia la estructura de cada pregunta es muy similar por lo que solo hay variaciones en cuanto al nombre de los DataFrame de acuerdo al requerimiento de la pregunta**
#
#
#
#
#
# **Gráficas**
# A continuación explicaremos el funcionamiento del código de cada una de las gráficas que aparecen dispuestas
#
# ![14.jpg](data:image/jpeg;base64,...)
#
# ![14.jpg](data:image/jpeg;base64,...)
#
# este código crea un gráfico de barras apiladas que visualiza la distribución de género de películas o series según el estrato socioeconómico. Cada barra representa un estrato, y las diferentes secciones de cada barra representan los diferentes géneros de películas o series dentro de ese estrato. El DataFrame estadoSocioe contiene información sobre las combinaciones de estrato y género.
#
# pivot es una operación que reorganiza los datos.  Se está realizando una operación de pivote en el DataFrame estadoSocioe.
# index=pGeneroPel indica que la columna pGeneroPel se utilizará como el índice (eje Y) en el DataFrame resultante.
# columns=pEstrato indica que la columna pEstrato se utilizará para crear columnas (eje x)
# values=0: indica que el valor en el DataFrame se tomará de la columna con etiqueta 0.
# fillna(0): se utiliza para rellenar los valores vacíos con ceros.
# pivot_df.plot(): se utiliza para crear un gráfico a partir del DataFrame pivot_df.
# kind='bar': indica que se creará un gráfico de barras.
# stacked=True: indica que las barras se apilarán en lugar de superponerse, lo que permitirá visualizar la distribución por cada combinación de estrato y género.
# figsize=(12, 8): establece el tamaño de la figura en pulgadas (ancho, alto).
#
# plt.xlabel(pGeneroPel) y plt.ylabel('Número de Personas'): Estas líneas establecen las etiquetas del eje X y el eje Y, respectivamente.
# plt.title('Distribución de Género de Películas o Series por Estrato Socioeconómico'): Esta línea establece el título del gráfico.
# plt.legend(title=pEstrato): Agrega una leyenda al gráfico con el título especificado en pEstrato. La leyenda mostrará las categorías de estrato.
# plt.show(): esta línea muestra el gráfico en la interfaz gráfica.
#
#
# **Gráfica de estado civil vs genero preferido**
#
# ![15.jpg](data:image/jpeg;base64,...)
#
#  ![15.jpg](data:image/jpeg;base64,...)
#
# este código crea un gráfico de barras apiladas que visualiza la distribución de género de películas o series según el estado civil. Cada barra representa un género cinematográfico, y las diferentes secciones de cada barra representan los diferentes estados civiles. El DataFrame estadoSocioe contiene información sobre las combinaciones de estrato y género.
#
# Genere=df1[[pGenero,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pGenero])
# Genere
#
# Esto crea un nuevo DataFrame llamado Genere a partir de df1. Se seleccionan dos columnas, pGenero y pGeneroPel, y luego se cuentan las ocurrencias de cada combinación única de valores. El resultado se organiza en un DataFrame con tres columnas: pGenero, pGeneroPel y el conteo de ocurrencias. Luego, se ordena el DataFrame por las columnas pGeneroPel y pGenero.
# pivot_df = Genere.pivot(index=pGeneroPel, columns=pGenero, values=0).fillna(0)
# Esta línea pivota el DataFrame Genere, lo que significa que reorganiza los datos para que los géneros estén en el eje X y las categorías de pGeneroPel se convierten en las filas. El argumento index especifica qué columna se utilizará como índice  pGeneroPel, columns especifica qué columna se utilizará para crear las columnas del nuevo DataFrame pGenero, y values especifica qué columna se utilizará para llenar el nuevo DataFrame. Cualquier valor faltante se rellena con 0.
# ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))
# Esto crea un gráfico de barras apiladas utilizando el DataFrame pivotado pivot_df. Los argumentos kind='bar' especifican que se trata de un gráfico de barras y stacked=True indica que las barras se apilarán una sobre otra en lugar de estar una al lado de la otra. El tamaño del gráfico se establece en 12 unidades de ancho y 8 unidades de alto.
# plt.xlabel(pGeneroPel)
# plt.ylabel('Número de Personas')
# plt.title('Distribución de Género de Películas o Series por Estado civil')
# plt.xlabel Agrega una etiqueta al eje X del gráfico, que representa la variable pGeneroPel.
# plt.ylabel Agrega una etiqueta al eje Y del gráfico, que representa el número de personas.
# plt.title Establece el título del grafico
# plt.legend(title=pGenero)
# plt.show()
# plt.legend Establece la leyenda de del grafico
# plt.show() muestra el grafico
#
# **Distribución de genero de  películas vs estado civil **
#
# ![18.jpg](data:image/jpeg;base64,...)
#
# ![17.jpg](data:image/jpeg;base64,...)
#
# este código genera un gráfico de barras apiladas que muestra la distribución de géneros cinematográficos por estado civil, utilizando los datos del DataFrame Genere. Cada barra representa un estado civil y está dividida en segmentos que representan los diferentes géneros cinematográficos.
# Genere=df1[[pGenero,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pGenero]) Genere
# Crea un nuevo DataFrame llamado Genere a partir de df1. Se seleccionan dos columnas, pGenero y pGeneroPel, y luego se cuentan las ocurrencias de cada combinación única de valores. El resultado se organiza en un DataFrame con tres columnas: pGenero, pGeneroPel y el conteo de ocurrencias. Luego, se ordena el DataFrame por las columnas pGeneroPel y pGenero.
# pivot_df = Genere.pivot(index= pivot_df = Genere.pivot(index=pGeneroPel, columns=pGenero, values=0).fillna(0)
# Pivota el DataFrame Genere, lo que significa que reorganiza los datos para que los géneros estén en el eje X y las categorías de pGeneroPel se convierten en las filas. El argumento index especifica qué columna se utilizará como índice (en este caso, pGeneroPel), columns especifica qué columna se utilizará para crear las columnas del nuevo DataFrame (en este caso, pGenero), y values especifica qué columna se utilizará para llenar el nuevo DataFrame (en este caso, el conteo de ocurrencias, que está en la columna con etiqueta 0). Cualquier valor faltante se rellena con 0.
# ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))
#
# Crea un gráfico de barras apiladas utilizando el DataFrame pivotado pivot_df. Los argumentos kind='bar' especifican que se trata de un gráfico de barras y stacked=True indica que las barras se apilarán una sobre otra en lugar de estar una al lado de la otra. El tamaño del gráfico se establece en 12 unidades de ancho y 8 unidades de alto.
# plt.xlabel(pGeneroPel)
# Agrega una etiqueta al eje X del gráfico, que representa la variable pGeneroPel.
# plt.ylabel('Número de Personas')
# Agrega una etiqueta al eje Y del gráfico, que representa el número de personas.
# plt.title('Distribución de Género de Películas o Series por Estado civil')
#
# Establece el título del gráfico.
# plt.legend(title=pGenero)
#
# Agrega una leyenda al gráfico, con el título definido por la variable pGenero.
# plt.show()
# Muestra el gráfico.
#
#
# **Distribución por rango de edad y género cinematográfico**
#
#  ![17.jpg](data:image/jpeg;base64,...)
#
#  ![17.jpg](data:image/jpeg;base64,...)
#
# Este código realiza una serie de operaciones para visualizar cómo se distribuye la preferencia de géneros cinematográficos en diferentes rangos de edad. Cada barra en el gráfico representa el número de personas que prefieren un género específico dentro de un rango de edad determinado.
#
# Asignación de Rangos de Edad:
# df_edad1.loc[:,"RangoEdad"] = "18-30"
# df_edad2.loc[:,"RangoEdad"] = "31-50"
# df_edad3.loc[:,"RangoEdad"] = ">50"
#
#  En este paso, se asigna el rango de edad "18-30" a la columna "RangoEdad" del DataFrame df_edad1. Esto se hace para indicar que las personas en este DataFrame pertenecen a este rango de edad.
# De manera similar, se asignan los rangos "31-50" y ">50" a las columnas "RangoEdad" de df_edad2 y df_edad3 respectivamente. Estos DataFrames deben contener información sobre personas en esos rangos de edad.
# Concatenación de DataFrames:
# df_graf_edad = pd.concat([df_edad1,df_edad2,df_edad3])
# Aquí, los tres DataFrames (df_edad1, df_edad2, df_edad3) se combinan verticalmente para formar uno solo llamado df_graf_edad. Esto significa que ahora contiene información sobre personas de los tres rangos de edad.
# Conteo de Preferencias de Género por Rango de Edad:
# df_final_edad = df_graf_edad[[pGeneroPel,"RangoEdad"]].value_counts().reset_index()
#
# Este paso cuenta cuántas personas prefieren cada género cinematográfico dentro de cada rango de edad. El resultado se almacena en df_final_edad.
# Pivotar el DataFrame:
# pivot_df_edad = df_final_edad.pivot(index=pGeneroPel, columns="RangoEdad", values=0).fillna(0)
# Se realiza una operación de pivote en el DataFrame df_final_edad para reorganizar los datos. Esto hace que los géneros estén en el eje X y los rangos de edad en el eje Y.
# Crear un Gráfico de Barras Apiladas:
# ax = pivot_df_edad.plot(kind='bar', stacked=True, figsize=(12, 8))
#
# Aquí se crea un gráfico de barras apiladas utilizando los datos del DataFrame pivotado. Este tipo de gráfico es útil para visualizar la distribución de preferencias de género dentro de cada rango de edad.
# Configurar Etiquetas y Título:
# plt.xlabel(pGeneroPel)
# Establece la etiqueta del eje X con el valor de la variable pGeneroPel.
# plt.ylabel('Número de Personas')
# Establece la etiqueta del eje Y como "Número de Personas".
# plt.title('Distribución de Género de Películas o Series por rango de edad')
#
# Asigna un título al gráfico.
# Mostrar Leyenda y Gráfico:
# plt.legend(title="RangoEdad")
#
# Agrega una leyenda al gráfico para indicar qué color representa cada rango de edad.
# plt.show()
# Muestra el gráfico en la salida.
#
# **Grafico cantidad de hijos vs gustos cinematográficos**
#
# ![17.jpg](data:image/jpeg;base64,...)
#
# ![17.jpg](data:image/jpeg;base64,...)
#
# Asignación de Etiqueta según la Cantidad de Hijos:
# En este grupo de código se asignan las cantidades de hijos en tres Data frames
# df_hijo1["Cant_hijos"] = "Sin hijos"
# df_hijo2["Cant_hijos"] = "Un hijo"
# df_hijo3["Cant_hijos"] = "Más de un hijo"
#
# Concatenación de DataFrames:
# df_graf_hijo = pd.concat([df_hijo1,df_hijo2,df_hijo3]): Combina verticalmente los tres DataFrames df_hijo1, df_hijo2 y df_hijo3 en uno solo llamado df_graf_hijo. Ahora contiene información sobre personas en diferentes categorías de cantidad de hijos.
# Conteo de Preferencias de Género por Cantidad de Hijos:
# df_final_hijo = df_graf_hijo[[pGeneroPel,"Cant_hijos"]].value_counts().reset_index()
#
# Este paso cuenta cuántas personas prefieren cada género cinematográfico en función de la cantidad de hijos que tienen. El resultado se almacena en df_final_hijo.
# Pivotar el DataFrame:
# pivot_df_hijo = df_final_hijo.pivot(index=pGeneroPel, columns="Cant_hijos", values=0).fillna(0)
#
# Se realiza una operación de pivote en el DataFrame df_final_hijo para reorganizar los datos. Esto hace que las categorías de cantidad de hijos estén en el eje X y los géneros en el eje Y.
# Crear un Gráfico de Barras Apiladas:
# ax = pivot_df_hijo.plot(kind='bar', stacked=True, figsize=(12, 8))
#
# Aquí se crea un gráfico de barras apiladas utilizando los datos del DataFrame pivotado. Este tipo de gráfico es útil para visualizar la distribución de preferencias de género dentro de cada categoría de cantidad de hijos.
# Configurar Etiquetas y Título:
# plt.xlabel(pGeneroPel)
# Establece la etiqueta del eje X con el valor de la variable pGeneroPel.
# plt.ylabel('Número de Personas')
# Establece la etiqueta del eje Y como "Número de Personas".
# plt.title('Distribución de Género de Películas o Series por rango de número hijos')
#  Asigna un título al gráfico.
# Mostrar Leyenda y Gráfico:
# plt.legend(title="Número de hijos")
#  Agrega una leyenda al gráfico para indicar qué color representa cada categoría de cantidad de hijos.
# plt.show()
# Muestra el gráfico en la salida.
# En resumen, este código proporciona una visualización de cómo la preferencia de géneros cinematográficos varía según el número de hijos que tienen las personas encuestadas. Cada barra en el gráfico representa el número de personas que prefieren un género específico dentro de una categoría de cantidad de hijos determinada.
#
#
# **Gustos cinematográficos vs situación laboral**
#
# ![24.jpg](data:image/jpeg;base64,...)
#
# ![23.jpg](data:image/jpeg;base64,...)
#
# Obtención de la Distribución de Preferencias por Situación Laboral:
# df_empleo = df1[[pGeneroPel,pEmpleo]].value_counts().reset_index()
# Este código toma las columnas pGeneroPel (género preferido) y pEmpleo (situación laboral) del DataFrame df1 y cuenta cuántas personas prefieren cada género para cada categoría de situación laboral. El resultado se almacena en el DataFrame df_empleo.
# Pivotar el DataFrame:
# pivot_df = df_empleo.pivot(index=pGeneroPel, columns=pEmpleo, values=0).fillna(0)
#
# Aquí se realiza una operación de pivote en el DataFrame df_empleo. Esto reorganiza los datos para que las categorías de situación laboral estén en el eje X y los géneros en el eje Y.
# Crear un Gráfico de Barras Apiladas:
# ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))
#
# Se crea un gráfico de barras apiladas utilizando los datos del DataFrame pivotado. Esto permite visualizar cómo la preferencia de género cinematográfico varía según la situación laboral.
# Configurar Etiquetas y Título:
# plt.xlabel(pGeneroPel)
# Establece la etiqueta del eje X con el valor de la variable pGeneroPel.
# plt.ylabel('Número de Personas')
# Establece la etiqueta del eje Y como "Número de Personas".
# plt.title('Distribución de Género de Películas o Series por situación laboral')
# Asigna un título al gráfico para indicar qué información se está representando.
# Mostrar Leyenda y Gráfico:
# plt.legend(title=pEmpleo)
# Agrega una leyenda al gráfico para indicar qué color representa cada categoría de situación laboral.
# plt.show()
# Muestra el gráfico en la salida.
# Este código proporciona una visualización de cómo la preferencia de géneros cinematográficos se distribuye entre diferentes situaciones laborales. Cada barra en el gráfico representa el número de personas que prefieren un género específico dentro de una categoría de situación laboral determinada.

# %% [markdown]
# # 1️⃣**. OBJETIVO GENERAL**
# * Plantee un objetivo general que le permita identificar el por qué quiere conocer esta información, para su posterior análisis.
#
# ## *🎯Identificar los factores que determinan o influyen en las preferencias de géneros cinematográficos comunes

# %% [markdown]
# # **2️⃣. ENCUESTA EN FORMULARIO DE GOOGLE**
#
# * Diseñe la encuesta en un formulario de Google, Office o el que crea conveniente o, si seleccionó la opción 2, guarde la evidencia de los datos encontrados.

# %% [markdown]
# Preguntas generales: A esta se refiere el programa cuando se habla de PREGUNTAS GENERALES (10 preguntas)
#
#
# ```
# # Aquí se definen cada una de las variables de las preguntas generales que se mostrarán más adelante
# ```

# %%
pEdad = "¿Cual es su edad?"                           #Pregunta general 1
pGenero = "¿Cual es su género?"                       #Pregunta general 2
pNatal = "¿Cual es su país de nacimiento?"            #Pregunta general 3
pResidencia = "¿Cual es su ciudad de residencia?"     #Pregunta general 4
pNivelAcademi = "¿Cual es su nivel académico?"        #Pregunta general 5
pEstadoCivil = "¿Cual es su estado civil?"            #Pregunta general 6
pHijos = "¿Cuantos hijos tiene?"                      #Pregunta general 7
pEmpleo = "¿Cual es su tipo de empleo?"               #Pregunta general 8
pVivienda = "¿Cual es su tipo de vivienda?"           #Pregunta general 9
pEstrato = "¿Cual es su estrato socioeconómico?"      #Pregunta general 10
pNacimiento = "¿Cual es su ciudad de nacimiento?"     #Pregunta general 11

# %% [markdown]
#  Preguntas específicas: A estas se refiere el programa cuando se habla de PREGUNTAS ESPECÍFICAS DE PELICULAS Y SERIES (8 preguntas)
#
#
# ```
# # Aquí se define cada una de las variables de las preguntas específicas que se mostrarán más adelante
# ```

# %%
pPreferencia = "¿Cual opción prefiere para ver películas o series?"                                                   #Pregunta específica 1
pFrecuencia = "¿Con qué frecuencia suele ver películas o series?"                                                     #Pregunta específica 2
pMomentoDia = "¿En qué momento del día suele ver películas o series?"                                                 #Pregunta específica 3
pFavStream = "¿Cuál es su plataforma de streaming favorita?"                                                          #Pregunta específica 4
pGeneroPel = "¿Qué género de películas o series prefiere?"                                                            #Pregunta específica 5
pCompa = "¿Le gusta ver películas o series en compañía de otras personas o prefiere hacerlo en solitario?"            #Pregunta específica 6
pPlan = "¿Suele planificar la visualización de películas o series con anticipación o lo hace de manera espontánea?"   #Pregunta específica 7
pDias = "¿Cuántos días a la semana ves series o películas?"                                                           #Pregunta específica 8

# %% [markdown]
# # 3️⃣**. LA ENCUESTA FUÉ REALIZADA A *123* NÚMERO DE PERSONAS**
# * Encuentre un mínimo de 50 personas, procure siempre la veracidad de los datos.

# %% [markdown]
# #4️⃣,5️⃣y6️⃣**. ALMACENAMIENTO DE DATOS EN .CSV**
# * Almacene la base de datos en un documento de Excel o similar.
# * Cree un archivo json o csv con la base de datos del archivo de Excel.
# * Diseñe una aplicación en Python donde pueda analizar los datos. Esta es la aplicación.

# %%
# IMPORTAR LIBRERÍAS
import pandas as pd  # Pandas se usa para la manipulación y análisis de datos tabulares, como dataframes.
import numpy as np   # Numpy proporciona soporte para arreglos multidimensionales y operaciones matemáticas en ellos.
import matplotlib.pyplot as plt  # Matplotlib es una biblioteca de visualización que se usa para crear gráficos y visualizaciones de datos.

# %%
# IMPORTAR EL ARCHIVO .CSV

# URL del archivo CSV en Google Drive (modificada)
url = "https://drive.google.com/uc?id=1iJWIdsDzAeWeQjEeZc4sCGl6MqfkQPo4" #ARCHIVO FINAL, CON 123 DATOS ✅
df1 = pd.read_csv(url)
df1  #Se muestran los dataset .csv
# Out:
#                           Fecha  ¿Cual es su edad? ¿Cual es su género?  \
# 0     2023/10/23 9:31:19 AM EST                 21           Masculino
# 1    2023/10/23 10:15:21 AM EST                 38            Femenino
# 2    2023/10/23 10:17:13 AM EST                 42           Masculino
# 3    2023/10/23 10:17:30 AM EST                 42           Masculino
# 4    2023/10/23 10:18:06 AM EST                 28           Masculino
# ..                          ...                ...                 ...
# 117   2023/10/23 9:01:17 PM EST                 21           Masculino
# 118  2023/10/23 10:12:16 PM EST                 17           Masculino
# 119  2023/10/23 10:13:42 PM EST                 34            Femenino
# 120   2023/10/24 8:58:05 PM EST                 30           Masculino
# 121   2023/10/25 3:08:36 PM EST                 30           Masculino
#
#     ¿Cual es su país de nacimiento? ¿Cual es su ciudad de nacimiento?  \
# ...

# %% [markdown]
# # 7️⃣**. TAREAS DE TABLAS Y GRÁFICOS PARA LAS VARIABLES**
# Desarrolle las siguientes tareas para cada una de las variables creadas con cada pregunta, la que usted planteó y las de la tabla:
#
# A. Tabla de frecuencias
#
# B. Medidas de tendencia central (Moda, Media y Mediana)
#
# C. Medidas de dispersión (Varianza y Desviación estándar)
#
# D. Medidas de posición (Cuartiles, quintiles y percentiles)
#
# E. Gráficos (Barras, histogramas, tortas)

# %% [markdown]
# # Ⓐ Tablas de frecuencia preguntas generales

# %% [markdown]
# **Tabla de frecuencia pregunta general 1**
#
# * pEdad = "¿Cuál es su edad?"

# %%
tEdad = df1[pEdad].value_counts().reset_index() # Crear una tabla de frecuencia de la columna 'pEdad' y resetear el índice
tEdad.columns = ['Edad', 'Frecuencia']  #Se añade el nombre de la colunmas del dataframe
tEdad  # Mostrar la tabla de frecuencia
# Out:
#     Edad  Frecuencia
# 0     25           9
# 1     19           8
# 2     31           8
# 3     29           8
# 4     30           7
# 5     20           7
# 6     21           6
# 7     28           6
# 8     27           6
# 9     42           5
# 10    26           4
# 11    33           4
# 12    23           4
# 13    38           4
# 14    22           4
# 15    37           4
# 16    17           3
# 17    32           3
# 18    34           3
# 19    24           3
# 20    50           2
# 21    18           2
# 22    45           2
# 23    36           1
# 24    75           1
# 25    61           1
# 26    41           1
# 27    35           1
# 28    40           1
# 29    53           1
# 30    47           1
# 31    46           1
# 32    68           1

# %% [markdown]
# **Tabla de frecuencia pregunta general 2**
# * pGenero = "¿Cuál es su género?"

# %%
tGenero = df1[pGenero].value_counts().reset_index()
tGenero.columns = ['Género', 'Frecuencia']
tGenero
# Out:
#                 Género  Frecuencia
# 0            Masculino          64
# 1             Femenino          56
# 2  Prefiero no decirlo           2

# %% [markdown]
# **Tabla de frecuencia pregunta general 3**
# * pNatal = "¿Cuál es su país de nacimiento?"

# %%
tNatal = df1[[pNatal]].value_counts().reset_index()
tNatal.columns = ['País nacimiento', 'Frecuencia']
tNatal
# Out:
#         País nacimiento  Frecuencia
# 0              Colombia         117
# 1                 Chile           2
# 2                Mexico           1
# 3  República Dominicana           1
# 4             Venezuela           1

# %% [markdown]
# **Tabla de frecuencia pregunta general 4**
# * pResidencia = "¿Cuál es su ciudad de residencia?"

# %%
tResidencia = df1[pResidencia].value_counts().reset_index()
tResidencia.columns = ['Ciudad residencia', 'Frecuencia']
tResidencia
# Out:
#              Ciudad residencia  Frecuencia
# 0                     Medellín          33
# 1                    Medellín           30
# 2                     Apartadó          11
# 3                       Cucuta           6
# 4                        Bello           5
# 5                      Cucuta            5
# 6                       Bogotá           3
# 7                    Apartadó            3
# 8                       Carepa           3
# 9                      Bogotá            2
# 10                        Cali           2
# 11                  Copacabana           2
# 12                      Itagüí           1
# 13                   Montería            1
# 14                      Unguia           1
# 15                  Facatativa           1
# 16                     Itagüí            1
# 17                  Fusagasugá           1
# 18                     Boston            1
# 19                    Rionegro           1
# 20             Ciénaga de oro            1
# ...

# %% [markdown]
# **Tabla de frecuencia pregunta general 5**
# * pNivelAcademi = "¿Cuál es su nivel académico?"

# %%
tNivelAcademico = df1[[pNivelAcademi]].value_counts().reset_index()
tNivelAcademico.columns = ['Nivel académico', 'Frecuencia']
tNivelAcademico
# Out:
#   Nivel académico  Frecuencia
# 0     Profesional          56
# 1       Tecnólogo          19
# 2    Bachillerato          18
# 3         Técnico          18
# 4        Posgrado          11

# %% [markdown]
# **Tabla de frecuencia pregunta general 6**
# * pEstadoCivil = "¿Cuál es su estado civil?"

# %%
tEstadoCivil = df1[[pEstadoCivil]].value_counts().reset_index()
tEstadoCivil.columns = ['Estado civil', 'Frecuencia']
tEstadoCivil
# Out:
#   Estado civil  Frecuencia
# 0      Soltero          81
# 1       Casado          27
# 2  Unión libre          13
# 3     Separado           1

# %% [markdown]
# **Tabla de frecuencia pregunta general 7**
# * pHijos = "¿Cuantos hijos tiene?"

# %%
tHijos = df1[[pHijos]].value_counts().reset_index()
tHijos.columns = ['Número hijos', 'Frecuencia']
tHijos
# Out:
#    Número hijos  Frecuencia
# 0             0          87
# 1             1          22
# 2             2           9
# 3             5           3
# 4             3           1

# %% [markdown]
# **Tabla de frecuencia pregunta general 8**
# * pEmpleo = "¿Cual es su tipo de empleo?"

# %%
tEmpleo = df1[[pEmpleo]].value_counts().reset_index()
tEmpleo.columns = ['Tipo de empleo', 'Frecuencia']
tEmpleo
# Out:
#   Tipo de empleo  Frecuencia
# 0         Formal          89
# 1       No posee          21
# 2       Informal          12

# %% [markdown]
# **Tabla de frecuencia pregunta general 9**
# * pVivienda = "¿Cual es su tipo de vivienda?"

# %%
tVivienda = df1[[pVivienda]].value_counts().reset_index()
tVivienda.columns = ['Tipo de vivienda', 'Frecuencia']
tVivienda
# Out:
#   Tipo de vivienda  Frecuencia
# 0        Arrendada          52
# 1         Familiar          36
# 2           Propia          34

# %% [markdown]
# **Tabla de frecuencia pregunta general 10**
# * pEstrato = "¿Cual es su estrato socioeconómico?"

# %%
tSocioeco = df1[pEstrato].value_counts().reset_index()
tSocioeco.columns = ['Estrato socioeconómico', 'Frecuencia']
tSocioeco
# Out:
#    Estrato socioeconómico  Frecuencia
# 0                       3          51
# 1                       2          36
# 2                       4          23
# 3                       1           6
# 4                       5           6

# %% [markdown]
# Tabla de frecuencia pregunta general 11
#
# pNacimiento = "¿Cual es su ciudad de nacimiento?"

# %%
tCiuNacimiento = df1[pNacimiento].value_counts().reset_index()
tCiuNacimiento.columns = ['Ciudad Nacimiento', 'Frecuencia']
tCiuNacimiento
# Out:
#     Ciudad Nacimiento  Frecuencia
# 0             Pereira           4
# 1             Florián           4
# 2   Castilla la Nueva           4
# 3             Sahagún           4
# 4           Manizales           4
# ..                ...         ...
# 61            Barbosa           1
# 62      Villavicencio           1
# 63          Sincelejo           1
# 64            Baranoa           1
# 65               Chia           1
#
# [66 rows x 2 columns]

# %% [markdown]
# # Ⓐ Tablas de frecuencia preguntas especificas - Peliculas y Series

# %% [markdown]
# **Tabla de frecuencia pregunta 1**
# * pPreferencia = "¿Cual opción prefiere para ver películas o series?"

# %%
tPreferencia = df1[pPreferencia].value_counts().reset_index()
tPreferencia.columns = ['Streaming o TV', 'Frecuencia']
tPreferencia
# Out:
#                   Streaming o TV  Frecuencia
# 0       Plataformas de streaming         110
# 1  Televisión por cable/satélite          12

# %% [markdown]
# **Tabla de frecuencia pregunta 2**
# * pFrecuencia = "¿Con qué frecuencia suele ver películas o series?"

# %%
tFrecuencia = df1[[pFrecuencia]].value_counts().reset_index()
tFrecuencia.columns = ['Frecuencia para ver películas o series', 'Frecuencia']
tFrecuencia
# Out:
#   Frecuencia para ver películas o series  Frecuencia
# 0                           Semanalmente          45
# 1                         Ocasionalmente          43
# 2                            Diariamente          25
# 3                           Mensualmente           9

# %% [markdown]
# **Tabla de frecuencia pregunta 3**
# * pMomentoDia = "¿En qué momento del día suele ver películas o series?"

# %%
tMomentoDia = df1[[pMomentoDia]].value_counts().reset_index()
tMomentoDia.columns = ['En qué momento suele ver', 'Frecuencia']
tMomentoDia
# Out:
#   En qué momento suele ver  Frecuencia
# 0                    Noche         106
# 1                    Tarde          16

# %% [markdown]
# **Tabla de frecuencia pregunta 4**
# * pFavStream = "¿Cuál es su plataforma de streaming favorita?"

# %%
tFavStream = df1[pFavStream].value_counts().reset_index()
tFavStream.columns = ['Plataforma streaming', 'Frecuencia']
tFavStream
# Out:
#    Plataforma streaming  Frecuencia
# 0               Netflix          79
# 1               HBO Max          16
# 2               Disney+           8
# 3    Amazon Prime Video           6
# 4       Sin preferencia           2
# 5                 Star+           2
# 6          Crunchyroll            1
# 7     Crunchyrollyroll            1
# 8                  Plez           1
# 9       Paginas piratas           1
# 10             TioAnime           1
# 11                   TG           1
# 12              Cuevana           1
# 13                 Plex           1
# 14     Crunchyrollyroll           1

# %% [markdown]
# **Tabla de frecuencia pregunta 5**
# * pGeneroPel = "¿Qué género de películas o series prefiere?"

# %%
tGeneroPel = df1[pGeneroPel].value_counts().reset_index()
tGeneroPel.columns = ['Género de peliculas o series', 'Frecuencia']
tGeneroPel
# Out:
#   Género de peliculas o series  Frecuencia
# 0                       Acción          23
# 1              Ciencia ficción          21
# 2                      Comedia          19
# 3                      Romance          13
# 4                        Drama          12
# 5                 Documentales          12
# 6                     Fantasía           9
# 7                     Aventura           6
# 8                       Terror           6
# 9                        Anime           1

# %% [markdown]
# **Tabla de frecuencia pregunta 6**
# * pCompa = "¿Le gusta ver películas o series en compañía de otras personas o prefiere hacerlo en solitario?"

# %%
tCompa = df1[[pCompa]].value_counts().reset_index()
tCompa.columns = ['Ver películas en compañía o solo', 'Frecuencia']
tCompa
# Out:
#   Ver películas en compañía o solo  Frecuencia
# 0                      En compañía          75
# 1                     En solitario          47

# %% [markdown]
# **Tabla de frecuencia pregunta 7**
# * pPlan = "¿Suele planificar la visualización de películas o series con anticipación o lo hace de manera espontánea?"

# %%
tPlan = df1[[pPlan]].value_counts().reset_index()
tPlan.columns = ['Planifica el ver películas', 'Frecuencia']
tPlan
# Out:
#    Planifica el ver películas  Frecuencia
# 0                  Espontáneo          96
# 1  Planifico con anticipación          26

# %% [markdown]
# **Tabla de frecuencia pregunta 8**
# * pDias = "¿Cuántas días a la semana ves series o películas?"

# %%
tDias = df1[[pDias]].value_counts().reset_index()
tDias.columns = ['Cuantos días a la semana', 'Frecuencia']
tDias
# Out:
#   Cuantos días a la semana  Frecuencia
# 0              Entre 2 y 3          47
# 1                   Solo 1          41
# 2                 Mas de 5          14
# 3              Entre 4 y 5          13
# 4                   No veo           7

# %% [markdown]
# # Ⓑ Medidas de tendencia central
# * Moda, Media y Mediana

# %% [markdown]
# ## Media

# %% [markdown]
# **Media edad**

# %%
mediaEdad = df1[pEdad].mean()
print(f"La media de edad en esta encuesta es de {round(mediaEdad,2)} años")
# Out:
# La media de edad en esta encuesta es de 29.82 años

# %% [markdown]
# **Media estrato**

# %%
mediaEstrato = df1[pEstrato].mean()
print(f"La media de estrato en esta encuesta es de {round(mediaEstrato,2)}")
# Out:
# La media de estrato en esta encuesta es de 2.89

# %% [markdown]
# **Media hijos**

# %%
mediaHijos = df1[pHijos].mean()
print(f"La media de hijos en esta encuesta es de {mediaHijos}")
# Out:
# La media de hijos en esta encuesta es de 0.47540983606557374

# %% [markdown]
# ## Moda

# %% [markdown]
# **Moda edad**

# %%
modaEdad = df1[pEdad].mode().iloc[0]
print(f"La moda de edad en esta encuesta es de {modaEdad} años")
# Out:
# La moda de edad en esta encuesta es de 25 años

# %% [markdown]
# **Moda estrato**

# %%
modaEstrato = df1[pEstrato].mode().iloc[0]
print(f"La moda de estrato en esta encuesta es {modaEstrato}")
# Out:
# La moda de estrato en esta encuesta es 3

# %% [markdown]
# **Moda hijos**

# %%
modaHijos = df1[pHijos].mode().iloc[0]
print(f"La moda de hijos en esta encuesta es {modaHijos}")
# Out:
# La moda de hijos en esta encuesta es 0

# %% [markdown]
# ## Mediana

# %% [markdown]
# **Mediana edad**

# %%
medianaEdad = df1[pEdad].median()
print(f"La mediana de edad en esta encuesta es de {int(medianaEdad)} años")
# Out:
# La mediana de edad en esta encuesta es de 28 años

# %% [markdown]
# **Mediana estrato**

# %%
medianaEstrato= df1[pEstrato].median()
print(f"La mediana de estrato en esta encuesta es de {int(medianaEstrato)}")
# Out:
# La mediana de estrato en esta encuesta es de 3

# %% [markdown]
# **Mediana hijos**

# %%
medianaHijos= df1[pHijos].median()
print(f"La mediana de hijos en esta encuesta es de {int(medianaHijos)}")
# Out:
# La mediana de hijos en esta encuesta es de 0

# %% [markdown]
# # Ⓒ Medidas de dispersion
# * Varianza y Desviación estándar

# %% [markdown]
# ## Varianza

# %% [markdown]
# **Varianza edad**

# %%
varianzaEdad = df1[pEdad].var()
print(f"La varianza de edad en esta encuesta es de {round(varianzaEdad,3)}")
# Out:
# La varianza de edad en esta encuesta es de 100.761

# %% [markdown]
# **Varianza estrato**

# %%
varianzaEstrato = df1[pEstrato].var()
print(f"La varianza de estrato en esta encuesta es de {round(varianzaEstrato,3)}")
# Out:
# La varianza de estrato en esta encuesta es de 0.873

# %% [markdown]
# **Varianza hijos**

# %%
varianzaHijos = df1[pHijos].var()
print(f"La varianza de hijos en esta encuesta es de {round(varianzaHijos,3)}")
# Out:
# La varianza de hijos en esta encuesta es de 0.946

# %% [markdown]
# ## Desviacion estandar

# %% [markdown]
# **Desviacion edad**

# %%
desviEdad = df1[pEdad].std()
print(f"La desviacion estandar de edad en esta encuesta es de {round(desviEdad,3)} años")
# Out:
# La desviacion estandar de edad en esta encuesta es de 10.038 años

# %% [markdown]
# **Desviacion estrato**

# %%
desviEstrato = df1[pEstrato].std()
print(f"La desviacion estandar de estrato en esta encuesta es de {round(desviEstrato,3)}")
# Out:
# La desviacion estandar de estrato en esta encuesta es de 0.934

# %% [markdown]
# **Desviacion hijos**

# %%
desviHijos = df1[pHijos].std()
print(f"La desviacion estandar de hijos en esta encuesta es de {round(desviHijos,3)}")
# Out:
# La desviacion estandar de hijos en esta encuesta es de 0.972

# %% [markdown]
# #Ⓓ Medidas de posición
# * Cuartiles, quintiles y percentiles

# %% [markdown]
# ## Cuartiles

# %% [markdown]
# **Cuartiles edad**

# %%
cuartilesEdad = df1[pEdad].quantile([0.25, 0.5, 0.75])
print(f"El valor de Q1 es {cuartilesEdad[0.25]}")
print(f"El valor de Q2 es {cuartilesEdad[0.5]}")
print(f"El valor de Q3 es {cuartilesEdad[0.75]}")
# Out:
# El valor de Q1 es 23.0
# El valor de Q2 es 28.0
# El valor de Q3 es 33.0

# %% [markdown]
# **Cuartiles estrato**

# %%
cuartilesEstrato = df1[pEstrato].quantile([0.25, 0.5, 0.75])
print(f"El valor de Q1 es {int(cuartilesEstrato[0.25])}")
print(f"El valor de Q2 es {int(cuartilesEstrato[0.5])}")
print(f"El valor de Q3 es {int(cuartilesEstrato[0.75])}")
# Out:
# El valor de Q1 es 2
# El valor de Q2 es 3
# El valor de Q3 es 3

# %% [markdown]
# **Cuartiles hijos**

# %%
cuartilesHijos = df1[pHijos].quantile([0.25, 0.5, 0.75])
print(f"El valor de Q1 es {int(cuartilesHijos[0.25])}")
print(f"El valor de Q2 es {int(cuartilesHijos[0.5])}")
print(f"El valor de Q3 es {int(cuartilesHijos[0.75])}")
# Out:
# El valor de Q1 es 0
# El valor de Q2 es 0
# El valor de Q3 es 1

# %% [markdown]
# ## Quintiles

# %% [markdown]
# **Quintiles edad**

# %%
quintilesEdad = df1[pEdad].quantile([0.2, 0.4, 0.6, 0.8])
print(f"El valor de Q1 es {quintilesEdad[0.2]}")
print(f"El valor de Q2 es {quintilesEdad[0.4]}")
print(f"El valor de Q3 es {quintilesEdad[0.6]}")
print(f"El valor de Q4 es {quintilesEdad[0.8]}")
# Out:
# El valor de Q1 es 21.0
# El valor de Q2 es 26.0
# El valor de Q3 es 30.0
# El valor de Q4 es 36.80000000000001

# %% [markdown]
# **Quintiles estrato**

# %%
quintilesEstrato = df1[pEstrato].quantile([0.2, 0.4, 0.6, 0.8])
print(f"El valor de Q1 es {int(quintilesEstrato[0.2])}")
print(f"El valor de Q2 es {int(quintilesEstrato[0.4])}")
print(f"El valor de Q3 es {int(quintilesEstrato[0.6])}")
print(f"El valor de Q4 es {int(quintilesEstrato[0.8])}")
# Out:
# El valor de Q1 es 2
# El valor de Q2 es 3
# El valor de Q3 es 3
# El valor de Q4 es 4

# %% [markdown]
# **Quintiles hijos**

# %%
quintilesHijos = df1[pHijos].quantile([0.2, 0.4, 0.6, 0.8])
print(f"El valor de Q1 es {int(quintilesHijos[0.2])}")
print(f"El valor de Q2 es {int(quintilesHijos[0.4])}")
print(f"El valor de Q3 es {int(quintilesHijos[0.6])}")
print(f"El valor de Q4 es {int(quintilesHijos[0.8])}")
# Out:
# El valor de Q1 es 0
# El valor de Q2 es 0
# El valor de Q3 es 0
# El valor de Q4 es 1

# %% [markdown]
# ## Percentiles

# %% [markdown]
# **Percentil edad**

# %%
percentilEdad = df1[pEdad].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
print(f"El valor de percentil 10 es {percentilEdad[0.1]} años")
print(f"El valor de percentil 25 es {percentilEdad[0.25]} años")
print(f"El valor de percentil 50 es {percentilEdad[0.50]} años")
print(f"El valor de percentil 75 es {percentilEdad[0.75]} años")
print(f"El valor de percentil 90 es {percentilEdad[0.90]} años")
# Out:
# El valor de percentil 10 es 19.1 años
# El valor de percentil 25 es 23.0 años
# El valor de percentil 50 es 28.0 años
# El valor de percentil 75 es 33.0 años
# El valor de percentil 90 es 42.0 años

# %% [markdown]
# **Percentil estrato**

# %%
percentilEstrato = df1[pEstrato].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
print(f"El valor de percentil 10 es {int(percentilEstrato[0.1])} ")
print(f"El valor de percentil 25 es {int(percentilEstrato[0.25])} ")
print(f"El valor de percentil 50 es {int(percentilEstrato[0.50])} ")
print(f"El valor de percentil 75 es {int(percentilEstrato[0.75])} ")
print(f"El valor de percentil 90 es {int(percentilEstrato[0.90])} ")
# Out:
# El valor de percentil 10 es 2
# El valor de percentil 25 es 2
# El valor de percentil 50 es 3
# El valor de percentil 75 es 3
# El valor de percentil 90 es 4

# %% [markdown]
# **Percentil hijos**

# %%
percentilHijos = df1[pHijos].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
print(f"El valor de percentil 10 es {int(percentilHijos[0.1])} ")
print(f"El valor de percentil 25 es {int(percentilHijos[0.25])} ")
print(f"El valor de percentil 50 es {int(percentilHijos[0.50])} ")
print(f"El valor de percentil 75 es {int(percentilHijos[0.75])} ")
print(f"El valor de percentil 90 es {int(percentilHijos[0.90])} ")
# Out:
# El valor de percentil 10 es 0
# El valor de percentil 25 es 0
# El valor de percentil 50 es 0
# El valor de percentil 75 es 1
# El valor de percentil 90 es 1

# %% [markdown]
# #Ⓔ Graficos generales
# * Barras y tortas

# %% [markdown]
# ## Edad

# %%
tEdadOr = tEdad.sort_index()
plt.figure(figsize=(10, 5))
tEdadOr.plot(kind='bar')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Edad')
plt.show()

# %% [markdown]
# ## Genero

# %%
plt.figure(figsize=(6, 6))
df1[pGenero].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Genero")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Pais de nacimiento

# %%
plt.figure(figsize=(10, 10))
df1[pNatal].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Pais de nacimiento")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Ciudad de residencia

# %%
tResidenciaO = tResidencia.sort_index()
plt.figure(figsize=(10, 7))
tResidenciaO.plot(kind='bar')
plt.xlabel('Ciudad de residencia')
plt.ylabel('Frecuencia')
plt.title('Ciudad de residencia')
plt.show()

# %% [markdown]
# ## Nivel academico

# %%
plt.figure(figsize=(6, 6))
df1[pNivelAcademi].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Nivel academico")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Estado civil

# %%
plt.figure(figsize=(6, 6))
df1[pEstadoCivil].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Estado civil")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Hijos

# %%
plt.figure(figsize=(6, 6))
df1[pHijos].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Cantidad de hijos")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Empleo

# %%
plt.figure(figsize=(6, 6))
df1[pEmpleo].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Tipo de empleo")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Vivienda

# %%
plt.figure(figsize=(6, 6))
df1[pVivienda].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Tipo de vivienda")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Estrato

# %%
tSocioecoO = tSocioeco.sort_index()
plt.figure(figsize=(7, 6))
tSocioecoO.plot(kind='bar')
plt.xlabel('Estrato')
plt.ylabel('Frecuencia')
plt.title('Estrato socioeconomico')
plt.show()

# %% [markdown]
# #Ⓔ Graficos especificos - Peliculas y Series
# * Barras y tortas

# %% [markdown]
# ## Plataforma de streaming

# %%
# Crear una figura de matplotlib con un tamaño de 6x6 pulgadas
plt.figure(figsize=(6, 6))

# Crear una gráfica de pastel a partir de los valores de la columna 'pPreferencia'
df1[pPreferencia].value_counts().plot(kind='pie', autopct='%1.1f%%')
# - kind='pie': Indica que queremos una gráfica de pastel.
# - autopct='%1.1f%%': Muestra los porcentajes de cada categoría en la gráfica con un decimal de precisión.

# Establecer un título para la gráfica
plt.title(pPreferencia)

# Eliminar la etiqueta del eje Y
plt.ylabel("")

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ## Frecuencia

# %%
plt.figure(figsize=(6, 6))
df1[pFrecuencia].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title(pFrecuencia)
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Momento del dia

# %%
plt.figure(figsize=(6, 6))
df1[pMomentoDia].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title(pMomentoDia)
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Plataforma favorita

# %%
# Ordenar el DataFrame por índice (en este caso, el índice es la columna 'Plataforma streaming')
tFavStreamO = tFavStream.sort_index()

# Establecer la columna 'Plataforma streaming' como el índice del DataFrame (Poner Titulo de columna en la tabla de frecuencias)
tFavStreamO.set_index('Plataforma streaming', inplace=True)

# Crear una figura para el gráfico con un tamaño de 10x5 pulgadas
plt.figure(figsize=(10, 5))

# Crear el gráfico de barras a partir de los datos en tFavStreamO
ax = tFavStreamO.plot(kind='bar')

# Establecer la etiqueta del eje x como 'Plataforma streaming'
plt.xlabel(pFavStream)

# Establecer la etiqueta del eje y como 'Frecuencia'
plt.ylabel('Frecuencia')

# Establecer el título del gráfico como 'Plataformas'
plt.title('Plataformas')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Genero

# %%
tGeneroPelO = tGeneroPel.sort_index()
tGeneroPelO.set_index('Género de peliculas o series', inplace=True)  #Titulo dataframe dentro de comilas '' del punto de tablas de frecuencias
plt.figure(figsize=(7, 5))
tGeneroPelO.plot(kind='bar')
plt.xlabel(pGeneroPel)
plt.ylabel('Frecuencia')
plt.title('Generos')
plt.show()

# %% [markdown]
# ## Compañia

# %%
plt.figure(figsize=(6, 6))
df1[pCompa].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title(pCompa)
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Planificacion

# %%
plt.figure(figsize=(6, 6))
df1[pPlan].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title(pPlan)
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Cuantos dias

# %%
plt.figure(figsize=(6, 6))
df1[pDias].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title(pDias)
plt.ylabel("")
plt.show()

# %% [markdown]
# # 8️⃣**. ANÁLISIS DE VARIABLES - TABLA QUE FILTRA LOS DATOS**
# Desarrolle en su aplicación un análisis de variables de acuerdo con las siguientes preguntas.
#
# Para identificar la pregunta que usted planteó usaremos la expresión {x}

# %% [markdown]
# A. ¿Cuántas personas {x} son mujeres?
#
# B. ¿Cuántas personas {x} son hombres?
#
# C. ¿Cuántas personas {x} son de otro género?
#
# D. ¿Cuántas personas {x} tienen más de 18 años y menos de 30 años?
#
# E. ¿Cuántas personas {x} tienen más de 30 años y menos de 50 años?
#
# F. ¿Cuántas personas {x} tienen más de 50 años?
#
# G. ¿Cuántas personas {x} son colombianas?
#
# H. ¿Cuántas personas {x} son extranjeras?
#
# I. ¿Cuántas personas {x} residen en su misma ciudad de nacimiento?
#
# J. ¿Cuántas personas {x} tienen determinado nivel académico?
#
# K. ¿Cuántas personas {x} tienen determinado nivel académico? **Es la misma pregunta que la J
#
# L. ¿Cuántas personas {x} tienen determinado estado civil?
#
# M. ¿Cuántas personas {x} no tienen hijos?
#
# N. ¿Cuántas personas {x} tienen 1 hijo?
#
# O. ¿Cuántas personas {x} tienen 2 hijos o más?
#
# P. ¿Cuántas personas {x} tienen empleos informales?
#
# Q. ¿Cuántas personas {x} tienen empleos formales?
#
# R. ¿Cuántas personas {x} no tienen empleo?
#
# S. ¿Cuántas personas {x} tienen casa propia?
#
# T. ¿Cuántas personas {x} residen en casa arrendada?
#
# U. ¿Cuántas personas {x} residen en casa familiar?
#
# V. ¿Cuántas personas {x} son de determinado estrato socioeconómico?

# %% [markdown]
# ## Ⓐ IDENTIDAD DE GENERO MUJER

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos son muejeres
df_femenino = df1[df1[pGenero]== "Femenino"]
df_final = df_femenino[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0          Comedia                                            9
# 1            Drama                                            8
# 2          Romance                                            8
# 3           Acción                                            7
# 4     Documentales                                            6
# 5  Ciencia ficción                                            6
# 6         Fantasía                                            6
# 7         Aventura                                            3
# 8           Terror                                            2
# 9            Anime                                            1

# %% [markdown]
# ## Ⓑ IDENTIDAD DE GENERO HOMBRE

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos son hombres
df_masculino = df1[df1[pGenero]== "Masculino"]
df_final = df_masculino[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                           15
# 1  Ciencia ficción                                           14
# 2          Comedia                                           10
# 3     Documentales                                            6
# 4          Romance                                            5
# 5            Drama                                            4
# 6           Terror                                            4
# 7         Fantasía                                            3
# 8         Aventura                                            3

# %% [markdown]
# ## Ⓒ IDENTIDAD DE OTRO GENERO

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos son de otro genero
df_otro = df1[df1[pGenero]== "Prefiero no decirlo"]
df_final = df_otro[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0  Ciencia ficción                                            1
# 1           Acción                                            1

# %% [markdown]
# ## Ⓓ MAYORES DE 18 Y MENORES DE 30

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos tienen más de 18 y menos de 30 años
df_edad1 = df1[ ((df1[pEdad]>= 18 )  & (df1[pEdad] <= 30) )]
df_final1 = df_edad1[pGeneroPel].value_counts().reset_index()
df_final1
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0          Comedia                                           15
# 1           Acción                                           14
# 2  Ciencia ficción                                           12
# 3          Romance                                            9
# 4     Documentales                                            7
# 5            Drama                                            6
# 6         Fantasía                                            6
# 7         Aventura                                            2
# 8           Terror                                            2
# 9            Anime                                            1

# %% [markdown]
# ##Ⓔ MAYORES DE 30 Y MENORES DE 50

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos tienen más de 30 y menos de 50 años
df_edad2 = df1[ ((df1[pEdad]> 30 )  & (df1[pEdad] <= 50) )]
df_final2 = df_edad2[pGeneroPel].value_counts().reset_index()
df_final2
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                            7
# 1  Ciencia ficción                                            7
# 2            Drama                                            6
# 3     Documentales                                            5
# 4         Aventura                                            4
# 5         Fantasía                                            3
# 6           Terror                                            3
# 7          Comedia                                            3
# 8          Romance                                            3

# %% [markdown]
# ##Ⓕ MAYORES DE 50

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos tienen más de 50 años
df_edad3 = df1[ ((df1[pEdad] > 50) )]
df_final3 = df_edad3[pGeneroPel].value_counts().reset_index()
df_final3
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0  Ciencia ficción                                            2
# 1           Acción                                            1
# 2          Comedia                                            1

# %% [markdown]
# ##Ⓖ PERSONAS COLOMBIANAS

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos son colombianas
df_pais = df1[df1[pNatal] == "Colombia"]
df_final = df_pais[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                           22
# 1  Ciencia ficción                                           21
# 2          Comedia                                           19
# 3          Romance                                           13
# 4            Drama                                           12
# 5     Documentales                                           11
# 6         Fantasía                                            8
# 7         Aventura                                            5
# 8           Terror                                            5
# 9            Anime                                            1

# %% [markdown]
# ##Ⓕ EXTRANJERAS

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos son EXTRANGERAS
df_extranjero = df1[df1[pNatal] != "Colombia"]
df_final = df_extranjero[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#           index  ¿Qué género de películas o series prefiere?
# 0      Fantasía                                            1
# 1        Acción                                            1
# 2  Documentales                                            1
# 3        Terror                                            1
# 4      Aventura                                            1

# %% [markdown]
# ##Ⓘ RESIDEN EN SU MISMA CIUDAD DE NACIMIENTO

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos residen en su misma ciudad ded nacimiento
df_residencia = df1[df1[pNacimiento] ==df1[pResidencia] ]
df_final = df_residencia[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#       index  ¿Qué género de películas o series prefiere?
# 0     Drama                                            1
# 1  Fantasía                                            1

# %% [markdown]
# ##Ⓙ NIVEL ACADEMICO

# %%
#Cuantas personas que eligen diferentes géneros cinematográficos tienen determinado nivel academico
df1[[pNivelAcademi,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pNivelAcademi])
# Out:
#    ¿Cual es su nivel académico? ¿Qué género de películas o series prefiere?  \
# 17                 Bachillerato                                      Acción
# 19                     Posgrado                                      Acción
# 1                   Profesional                                      Acción
# 10                    Tecnólogo                                      Acción
# 15                      Técnico                                      Acción
# 32                  Profesional                                       Anime
# 37                     Posgrado                                    Aventura
# 13                  Profesional                                    Aventura
# 36                    Tecnólogo                                    Aventura
# 30                      Técnico                                    Aventura
# 21                 Bachillerato                             Ciencia ficción
# ...

# %% [markdown]
# ## Ⓛ ESTADO CIVIL

# %%
# Ⓛ Cuantas personas que eligen diferentes géneros cinematográficos tienen determinado estado civil
estadoCivil = df1[[pEstadoCivil,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pEstadoCivil])

# %% [markdown]
# ##Ⓜ︎ NO TIENEN HIJOS

# %%
# Ⓜ︎ Cuantas personas que eligen diferentes géneros cinematográficos no tienen hijos
df_hijo1 = df1[df1[pHijos]==0]
df_final = df_hijo1[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0  Ciencia ficción                                           15
# 1           Acción                                           15
# 2          Comedia                                           14
# 3          Romance                                           11
# 4            Drama                                            8
# 5     Documentales                                            8
# 6         Fantasía                                            6
# 7         Aventura                                            5
# 8           Terror                                            4
# 9            Anime                                            1

# %% [markdown]
# ##Ⓝ TIENEN 1 HIJO

# %%
# Ⓝ Cuantas personas que eligen diferentes géneros cinematográficos tienen 1 hijo
df_hijo2 = df1[df1[pHijos]==1]
df_final = df_hijo2[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                            7
# 1  Ciencia ficción                                            4
# 2         Fantasía                                            3
# 3          Comedia                                            3
# 4            Drama                                            2
# 5     Documentales                                            2
# 6           Terror                                            1

# %% [markdown]
# ##Ⓞ TIENEN 2 HIJOS O MÁS

# %%
# Ⓞ Cuantas personas que eligen diferentes géneros cinematográficos tienen 2 hijos o más
df_hijo3 = df1[df1[pHijos]>= 2]
df_final = df_hijo3[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0            Drama                                            2
# 1     Documentales                                            2
# 2          Comedia                                            2
# 3          Romance                                            2
# 4  Ciencia ficción                                            2
# 5           Terror                                            1
# 6         Aventura                                            1
# 7           Acción                                            1

# %% [markdown]
# ##Ⓟ TIENEN EMPLEOS INFORMALES

# %%
# Ⓟ Cuantas personas que eligen diferentes géneros cinematográficos tienen empleos informales
df_pEmpleo = df1[df1[pEmpleo]=="Informal"]
df_final = df_pEmpleo[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0          Romance                                            3
# 1  Ciencia ficción                                            2
# 2           Terror                                            2
# 3            Drama                                            1
# 4     Documentales                                            1
# 5           Acción                                            1
# 6          Comedia                                            1
# 7         Fantasía                                            1

# %% [markdown]
# ##Ⓠ TIENEN EMPLEOS FORMALES

# %%
# Ⓠ Cuantas personas que eligen diferentes géneros cinematográficos tienen empleos formales
df_pEmpleo = df1[df1[pEmpleo]=="Formal"]
df_final = df_pEmpleo[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                           19
# 1  Ciencia ficción                                           15
# 2          Comedia                                           13
# 3            Drama                                           10
# 4          Romance                                           10
# 5         Fantasía                                            7
# 6     Documentales                                            7
# 7         Aventura                                            4
# 8           Terror                                            3
# 9            Anime                                            1

# %% [markdown]
# ##Ⓡ NO TIENEN EMPLEO

# %%
# Ⓡ Cuantas personas que eligen diferentes géneros cinematográficos no tienen empleo
df_pEmpleo = df1[df1[pEmpleo]=="No posee"]
df_final = df_pEmpleo[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0          Comedia                                            5
# 1  Ciencia ficción                                            4
# 2     Documentales                                            4
# 3           Acción                                            3
# 4         Aventura                                            2
# 5           Terror                                            1
# 6         Fantasía                                            1
# 7            Drama                                            1

# %% [markdown]
# ##Ⓢ TIENEN CASA PROPIA

# %%
# Ⓢ Cuantas personas que eligen diferentes géneros cinematográficos tienen casa propia
df_pVivienda = df1[df1[pVivienda]=="Propia"]
df_final = df_pVivienda[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0  Ciencia ficción                                            9
# 1     Documentales                                            5
# 2         Fantasía                                            4
# 3          Comedia                                            4
# 4            Drama                                            3
# 5           Terror                                            3
# 6           Acción                                            3
# 7          Romance                                            2
# 8         Aventura                                            1

# %% [markdown]
# ##Ⓣ RESIDEN EN CASA ARRENDADA

# %%
# Ⓣ Cuantas personas que eligen diferentes géneros cinematográficos residen en casa arrendada
df_pVivienda = df1[df1[pVivienda]=="Arrendada"]
df_final = df_pVivienda[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                           13
# 1          Comedia                                           10
# 2  Ciencia ficción                                            7
# 3          Romance                                            6
# 4            Drama                                            5
# 5     Documentales                                            4
# 6         Fantasía                                            4
# 7         Aventura                                            2
# 8           Terror                                            1

# %% [markdown]
# ##Ⓤ RESIDEN EN CASA FAMILIAR

# %%
# Ⓤ Cuantas personas que eligen diferentes géneros cinematográficos residen en casa familiar
df_pVivienda = df1[df1[pVivienda]=="Familiar"]
df_final = df_pVivienda[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0           Acción                                            7
# 1          Comedia                                            5
# 2          Romance                                            5
# 3  Ciencia ficción                                            5
# 4            Drama                                            4
# 5     Documentales                                            3
# 6         Aventura                                            3
# 7           Terror                                            2
# 8         Fantasía                                            1
# 9            Anime                                            1

# %% [markdown]
# ##Ⓥ SON DE DETERMINADO ESTRATO SOCIOECONÓMICO

# %%
# Ⓥ Cuantas personas que eligen diferentes géneros cinematográficos son de determinado estrato socioeconómico
estadoSocioe=df1[[pEstrato,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pEstrato])
estadoSocioe
# Out:
#     ¿Cual es su estrato socioeconómico?  \
# 20                                    1
# 12                                    2
# 2                                     3
# 3                                     4
# 9                                     5
# 25                                    3
# 21                                    3
# 14                                    4
# 23                                    1
# 4                                     2
# 0                                     3
# 26                                    4
# 32                                    1
# 7                                     2
# 1                                     3
# 27                                    4
# 31                                    1
# 13                                    2
# 10                                    3
# 15                                    4
# 29                                    1
# 5                                     2
# ...

# %%
#EJEMPLO
# [pGenero,pGeneroPel,pEdad]
df1[[pGenero,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pGenero])
# Out:
#     ¿Cual es su género? ¿Qué género de películas o series prefiere?   0
# 6              Femenino                                      Acción   7
# 0             Masculino                                      Acción  15
# 19  Prefiero no decirlo                                      Acción   1
# 18             Femenino                                       Anime   1
# 15             Femenino                                    Aventura   3
# 14            Masculino                                    Aventura   3
# 9              Femenino                             Ciencia ficción   6
# 1             Masculino                             Ciencia ficción  14
# 20  Prefiero no decirlo                             Ciencia ficción   1
# 3              Femenino                                     Comedia   9
# 2             Masculino                                     Comedia  10
# 8              Femenino                                Documentales   6
# ...

# %%
df_p_terror = df1[ ((df1[pEdad]>= 18 )  & (df1[pEdad] <= 30) )]
df_final = df_p_terror[pGeneroPel].value_counts().reset_index()
df_final
# Out:
#              index  ¿Qué género de películas o series prefiere?
# 0          Comedia                                           15
# 1           Acción                                           14
# 2  Ciencia ficción                                           12
# 3          Romance                                            9
# 4     Documentales                                            7
# 5            Drama                                            6
# 6         Fantasía                                            6
# 7         Aventura                                            2
# 8           Terror                                            2
# 9            Anime                                            1

# %% [markdown]
# #9️⃣**. GRÁFICOS Y CONCLUSIONES**
# Diseñe gráficos en su aplicación de Python para presentar un informe de conclusiones al respecto del proyecto. Estas conclusiones pueden ir en campos de texto del notebook haciendo referencia a la gráfica correspondiente.

# %%
# Ⓥ estadoSocioe es el DataFrame con las combinaciones de estrato y género

# Pivotar el DataFrame para que los géneros estén en el eje X
pivot_df = estadoSocioe.pivot(index=pGeneroPel, columns=pEstrato, values=0).fillna(0)

# Crear un gráfico de barras apiladas
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar etiquetas y título
plt.xlabel(pGeneroPel)
plt.ylabel('Número de Personas')
plt.title('Distribución de Género de Películas o Series por Estrato Socioeconómico')

# Mostrar leyenda
plt.legend(title=pEstrato)

# Mostrar el gráfico
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Según el gráfico anterior, la distribución por estrato socioeconómico, las personas de mayor estrato socioeconómico prefieren las películas de acción, y prefieren mucho menos la ciencia ficción, comedia, drama y romance.

# %%
# Ⓛ estadoCivil es el DataFrame con las combinaciones de estrato y género

# Pivotar el DataFrame para que los géneros estén en el eje X
pivot_df = estadoCivil.pivot(index=pGeneroPel, columns=pEstadoCivil, values=0).fillna(0)

# Crear un gráfico de barras apiladas
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar etiquetas y título
plt.xlabel(pGeneroPel)
plt.ylabel('Número de Personas')
plt.title('Distribución de Género de Películas o Series por Estado civil')

# Mostrar leyenda
plt.legend(title=pEstadoCivil)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Los que están en unión libre prefieren acción y comedia, sin embargo, la distribución de la muestra no es determinante, ya que la mayoría de la muestra es soltero, por lo que se distribuye homogeneamente.
# Los que viven en union libre no prefieren Anime, ni Aventura, ni Romance, ni Terror.
#
# El Anime es un género que no es preferido por las personas.

# %%
# Ⓥ Cuantas personas que eligen diferentes géneros cinematográficos son de determinado estrato socioeconómico
Genere=df1[[pGenero,pGeneroPel]].value_counts().reset_index().sort_values(by = [pGeneroPel,pGenero])
Genere

#  es el DataFrame con las combinaciones

# Pivotar el DataFrame para que los géneros estén en el eje X
pivot_df = Genere.pivot(index=pGeneroPel, columns=pGenero, values=0).fillna(0)

# Crear un gráfico de barras apiladas
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar etiquetas y título
plt.xlabel(pGeneroPel)
plt.ylabel('Número de Personas')
plt.title('Distribución de Género de Películas o Series por Estado civil')

# Mostrar leyenda
plt.legend(title=pGenero)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# A los hombres les gusta más la acción y ciencia ficción, y a las mujeres la comedia y el romance. Los hombres duplican en los gustos por la acción y ciencia ficción.

# %%
# Ⓥ Cuantas personas que eligen diferentes géneros cinematográficos son de determinado Rango de edad

df_edad1.loc[:,"RangoEdad"] = "18-30"
df_edad2.loc[:,"RangoEdad"] = "31-50"
df_edad3.loc[:,"RangoEdad"] = ">50"
df_graf_edad = pd.concat([df_edad1,df_edad2,df_edad3])
df_final_edad = df_graf_edad[[pGeneroPel,"RangoEdad"]].value_counts().reset_index()


# Pivotar el DataFrame para que los géneros estén en el eje X
pivot_df_edad = df_final_edad.pivot(index=pGeneroPel, columns="RangoEdad", values=0).fillna(0)

# Crear un gráfico de barras apiladas
ax = pivot_df_edad.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar etiquetas y título
plt.xlabel(pGeneroPel)
plt.ylabel('Número de Personas')
plt.title('Distribución de Género de Películas o Series por rango de edad')

# Mostrar leyenda
plt.legend(title="RangoEdad")

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-113-d67171ffe919>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_edad1.loc[:,"RangoEdad"] = "18-30"
# <ipython-input-113-d67171ffe919>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_edad2.loc[:,"RangoEdad"] = "31-50"
# <ipython-input-113-d67171ffe919>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_hijo1["Cant_hijos"] = "Sin hijos"
df_hijo2["Cant_hijos"] = "Un hijo"
df_hijo3["Cant_hijos"] = "Más de un hijo"

df_graf_hijo = pd.concat([df_hijo1,df_hijo2,df_hijo3])
df_final_hijo = df_graf_hijo[[pGeneroPel,"Cant_hijos"]].value_counts().reset_index()

# Pivotar el DataFrame para que los géneros estén en el eje X
pivot_df_hijo = df_final_hijo.pivot(index=pGeneroPel, columns="Cant_hijos", values=0).fillna(0)

# Crear un gráfico de barras apiladas
ax = pivot_df_hijo.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar etiquetas y título
plt.xlabel(pGeneroPel)
plt.ylabel('Número de Personas')
plt.title('Distribución de Género de Películas o Series por rango de número hijos')

# Mostrar leyenda
plt.legend(title="Número de hijos")

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-117-64c8c7c874e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hijo1["Cant_hijos"] = "Sin hijos"
# <ipython-input-117-64c8c7c874e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hijo2["Cant_hijos"] = "Un hijo"
# <ipython-input-117-64c8c7c874e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# La mayoría no tiene hijos, los que tiene mas de un hijo no les gusta fantasia, los que tienen un hijo no ven ni romance ni aventura

# %%
# Pivotar el DataFrame para que los géneros estén en el eje X

df_empleo = df1[[pGeneroPel,pEmpleo]].value_counts().reset_index()
df_empleo
pivot_df = df_empleo.pivot(index=pGeneroPel, columns=pEmpleo, values=0).fillna(0)

# Crear un gráfico de barras apiladas
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar etiquetas y título
plt.xlabel(pGeneroPel)
plt.ylabel('Número de Personas')
plt.title('Distribución de Género de Películas o Series por situación laboral')

# Mostrar leyenda
plt.legend(title=pEmpleo)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# La mayoria tienen empleo formal, a los que cuentan con empleo informal no les gusta la aventura, y a los desempleados no les gusta el romance

# %% [markdown]
# Conclusiones: se analisaron en las graficas la variables que podrian determinar el impacto en las preferencias de los generos cinematograficos en el publico general por lo que la preguntas que se excluyeron es por que su informacion no es cuncluyente o relevante para el objetivo principal de este proyecto

# %% [markdown]
# En terminos generales: el genero de anime y terror es el menos elegido por el publico a diferencia de los generos de accion y ciencia ficcion que son los preferidos

# %% [markdown]
# El mayor numero de encuestas fueron realizadas por hombres y a estos les gusta mas el género de acción, mientras que las mujeres prefieren el género de comedia
